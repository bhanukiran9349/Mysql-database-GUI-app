# %%
# database world is used. 
import tkinter as tk
import mysql.connector 
from tkinter import *
  
def submitact():
     
    user = Username.get()
    passw = password.get()
    data= database.get()

    logintodb(user, passw, data)
  
 
def logintodb(user, passw, data):
     
    # If password is enetered by the 
    # user
    if passw:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     password = passw,
                                     db =data)
        cursor = db.cursor()
         
    # If no password is enetered by the
    # user
    else:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     data =data)
        cursor = db.cursor()
def databases():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SHOW DATABASES")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='databases',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=0)
        i=i+1
    db.close()


def query1():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute(" SELECT COUNT(Id) AS '# of cities' FROM city;")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text=' ID',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='city',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='Name',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='CountryCode',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='District',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='Population',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=5)      
        i=i+1
        db.close()  
def query2():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SELECT Name, District FROM city WHERE District = 'New York';") 
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text=' ID',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='city',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='Name',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='CountryCode',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='District',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='Population',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=5)      
        i=i+1
        db.close()  
def query3():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SELECT * FROM city WHERE Name = 'Bratislava';")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text=' ID',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='city',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='Name',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='CountryCode',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='District',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='Population',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=5)   
        i=i+1
        db.close()

def query4():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SELECT Name, HeadOfState FROM country WHERE Name = 'United States';")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text=' ID',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='city',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='Name',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='CountryCode',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='District',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='Population',borderwidth=1, relief='ridge',anchor='w',bg='blue')
            e.grid(row=0,column=5)
        i=i+1
        db.close()
        
def inner_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT city.name, countrylanguage.language FROM city INNER JOIN countrylanguage ON city.countrycode = countrylanguage.countrycode;")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1 
        db.close()
        
def input_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute(savequery1.get())
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1 
        db.close()


root = tk.Tk()
root.geometry("1100x1000")
root.configure(bg='black')
root.title("DBMS Login Page") 

# Definging the first row
welcome = tk.Label(root, text ="GET INTO BHANU KIRAN DATABASE", fg = "blue", bg = "black",font = "Helvetica 24 bold italic")
welcome.place(x = 350, y = 20)

lblfrstrow = tk.Label(root, text ="USERNAME:", bg='blue',font = "Helvetica 12 bold italic")
lblfrstrow.place(x = 50, y = 50)
 
Username = tk.Entry(root, width = 35)
Username.place(x = 160, y = 50, width = 100)
  
lblsecrow = tk.Label(root, text ="PASSWORD:", bg='blue',font = "Helvetica 12 bold italic")
lblsecrow.place(x = 50, y = 80)
 
password = tk.Entry(root, width = 35)
password.place(x = 160, y = 80, width = 100)

lblthrdrow = tk.Label(root, text ="DATABASE:", bg='blue', font = "Helvetica 12 bold italic")
lblthrdrow.place(x = 50, y = 110)
 
database = tk.Entry(root, width = 35)
database.place(x = 160, y = 110, width = 100)

 
submitbtn = tk.Button(root, text ="LOGIN", font = "Helvetica 12 bold italic",
                      bg ='blue', command = submitact)
submitbtn.place(x = 100, y = 150, width = 155)

welcome1 = tk.Label(root, text ="PRE-DEFINED QUERIES:", fg = "blue", bg = "black",font = "Helvetica 16 bold italic")
welcome1.place(x = 50, y = 200)

base = tk.Button(root, text ="Databases", font = "Helvetica 12 bold italic",
                      bg ='blue', command = databases)
base.place(x = 150, y = 250, width = 155)
cond1 = tk.Button(root, text ="COUNT OF CITIES", font = "Helvetica 12 bold italic",
                      bg ='blue', command = query1)
cond1.place(x = 150, y = 300, width = 555)
cond2 = tk.Button(root, text ="ALL NAMES FROM NEWYORK DISTRICT", font = "Helvetica 12 bold italic",
                      bg ='blue', command = query2)
cond2.place(x = 150, y = 350, width = 555)
cond3 = tk.Button(root, text ="ALL RECORDS FROM BRATISLAVA DISTRICT", font = "Helvetica 12 bold italic",
                      bg ='blue', command = query3)
cond3.place(x = 150, y = 400, width = 555)
cond4 = tk.Button(root, text ="HEAD OF STATE FROM UNITED STATES", font = "Helvetica 12 bold italic",
                      bg ='blue', command = query4)
cond4.place(x = 150, y = 450, width = 555)

inner= tk.Button(root, text ="INNERJOIN",font = "Helvetica 12 bold italic",
                      bg ='blue', command = inner_query)
inner.place(x = 150, y = 500, width = 555)

welcome1 = tk.Label(root, text ="USER-DEFINED QUERIES:", fg = "blue", bg = "black",font = "Helvetica 16 bold italic")
welcome1.place(x = 50, y = 550)

query = tk.Label(root, text ="ENTER THE QUERY:", bg='black',font = "Helvetica 14 bold italic"  )
query.place(x = 150, y = 600)

cond5= tk.Button(root, text ="INPUT", font = "Helvetica 12 bold italic",
                      bg ='blue', command = input_query)
cond5.place(x = 150, y = 650, width = 155)
 
savequery1 = tk.Entry(root, width = 35)
savequery1.place(x = 300, y = 600, width = 700)

root.mainloop()
